# %% [markdown]
# # Jule's holiday preferences

# %% [markdown]
# <font color='blue'>This notebook will give you an insight of the holiday type Jule loves and show you a video how her perfect holiday could look like.</font>

# %%
def name ():
    name_input = input("My name is ")
name ()
# Out:
# My name is Jule

# %% [markdown]
# ![Jule.png](attachment:Jule.png)

# %%
def holiday ():
    holiday_input = input("What are your 3 most important requirements for a great holiday? [^1] ")
    #return holiday_input
    
holiday ()
# Out:
# What are your 3 most important requirements for a great holiday? [^1] Sun, Sea, Mountains

# %% [markdown]
# ![holiday.jpeg](attachment:holiday.jpeg)

# %% [markdown]
# [^1]: *The function asks Jule to explain her holiday preferences*

# %% [markdown]
# # <font color='darkblue'> Things that Jule loves to do on holidays</font>
#
# - Outdoor activites
# - Eating great local food
# - Read a good book

# %% [markdown]
# # <font color='darkblue'> If you want to have an impression of Jule's perfect holiday locations, watch this youtube video:</font>

# %%
from IPython.display import HTML

# Youtube
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/YHusujC8MOw?rel=0&amp;controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/YHusujC8MOw?rel=0&amp;controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>
