# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json() #equal to soup as it is already in the right json format which python understands
results
# Out:
# 200
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'completed': False},
#  {'userId': 1,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'completed': True},
#  {'userId': 1,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'completed': True},
#  {'userId': 2,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'completed': False},
#  {'userId': 2,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'completed': True},
#  {'userId': 2,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'completed': False},
#  {'userId': 2,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'completed': False},
#  {'userId': 2,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'completed': True},
#  {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True},
#  {'userId': 2,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'completed': True},
#  {'userId': 2,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'completed': False},
#  {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False},
#  {'userId': 2,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'completed': True},
#  {'userId': 2,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'completed': False},
#  {'userId': 2,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'completed': False},
#  {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False},
#  {'userId': 2,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'completed': False},
#  {'userId': 2,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'completed': True},
#  {'userId': 2,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'completed': True},
#  {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False},
#  {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False},
#  {'userId': 2,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'completed': False},
#  {'userId': 2,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'completed': True},
#  {'userId': 3,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'completed': False},
#  {'userId': 3,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'completed': False},
#  {'userId': 3,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'completed': True},
#  {'userId': 3,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'completed': True},
#  {'userId': 3,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'completed': False},
#  {'userId': 3,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'completed': False},
#  {'userId': 3,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'completed': False},
#  {'userId': 3,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'completed': False},
#  {'userId': 3,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'completed': True},
#  {'userId': 3,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'completed': False},
#  {'userId': 3,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'completed': False},
#  {'userId': 3,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'completed': False},
#  {'userId': 3,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'completed': True},
#  {'userId': 3,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'completed': True},
#  {'userId': 3,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'completed': True},
#  {'userId': 3,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'completed': False},
#  {'userId': 3,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'completed': False},
#  {'userId': 3,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'completed': True},
#  {'userId': 4,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'completed': True},
#  {'userId': 4,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'completed': False},
#  {'userId': 4,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'completed': True},
#  {'userId': 4,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'completed': False},
#  {'userId': 4,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'completed': False},
#  {'userId': 4,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'completed': False},
#  {'userId': 4,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'completed': False},
#  {'userId': 4,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'completed': False},
#  {'userId': 4,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'completed': False},
#  {'userId': 4,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'completed': False},
#  {'userId': 4, 'id': 71, 'title': 'aut velit saepe ullam', 'completed': False},
#  {'userId': 4,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'completed': False},
#  {'userId': 4,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'completed': True},
#  {'userId': 4,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'completed': False},
#  {'userId': 4,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'completed': False},
#  {'userId': 4, 'id': 76, 'title': 'sequi dolorem sed', 'completed': True},
#  {'userId': 4,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'completed': False},
#  {'userId': 4,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'completed': False},
#  {'userId': 4, 'id': 79, 'title': 'eum ipsa maxime ut', 'completed': True},
#  {'userId': 4,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'completed': True},
#  {'userId': 5, 'id': 81, 'title': 'suscipit qui totam', 'completed': True},
#  {'userId': 5,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'completed': False},
#  {'userId': 5,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'completed': True},
#  {'userId': 5,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'completed': False},
#  {'userId': 5, 'id': 85, 'title': 'et quia ad iste a', 'completed': True},
#  {'userId': 5,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'completed': False},
#  {'userId': 5, 'id': 89, 'title': 'sequi ut omnis et', 'completed': True},
#  {'userId': 5,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'completed': True},
#  {'userId': 5,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'completed': True},
#  {'userId': 5, 'id': 92, 'title': 'in omnis laboriosam', 'completed': True},
#  {'userId': 5,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'completed': True},
#  {'userId': 5,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'completed': False},
#  {'userId': 5,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'completed': True},
#  {'userId': 5,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'completed': False},
#  {'userId': 5,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'completed': False},
#  {'userId': 5,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'completed': True},
#  {'userId': 5,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'completed': False},
#  {'userId': 5,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'completed': False},
#  {'userId': 6,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'completed': False},
#  {'userId': 6, 'id': 102, 'title': 'sed ab consequatur', 'completed': False},
#  {'userId': 6,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'completed': False},
#  {'userId': 6,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'completed': False},
#  {'userId': 6,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'completed': True},
#  {'userId': 6,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'completed': True},
#  {'userId': 6,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'completed': False},
#  {'userId': 6,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'completed': True},
#  {'userId': 6,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'completed': True},
#  {'userId': 6, 'id': 110, 'title': 'aut aut ea corporis', 'completed': True},
#  {'userId': 6,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'completed': False},
#  {'userId': 6,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'completed': False},
#  {'userId': 6,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'completed': False},
#  {'userId': 6,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'completed': False},
#  {'userId': 6, 'id': 115, 'title': 'sed et ea eum', 'completed': False},
#  {'userId': 6,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'completed': True},
#  {'userId': 6,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'completed': False},
#  {'userId': 6,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'completed': False},
#  {'userId': 6,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'completed': False},
#  {'userId': 6,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'completed': False},
#  {'userId': 7,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'completed': True},
#  {'userId': 7,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'completed': True},
#  {'userId': 7,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'completed': False},
#  {'userId': 7, 'id': 124, 'title': 'qui consectetur id', 'completed': False},
#  {'userId': 7,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'completed': False},
#  {'userId': 7,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'completed': True},
#  {'userId': 7,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'completed': False},
#  {'userId': 7,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'completed': False},
#  {'userId': 7,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'completed': True},
#  {'userId': 7, 'id': 131, 'title': 'qui ea incidunt quis', 'completed': False},
#  {'userId': 7,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'completed': True},
#  {'userId': 7,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'completed': True},
#  {'userId': 7,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'completed': False},
#  {'userId': 7,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'completed': False},
#  {'userId': 7,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'completed': False},
#  {'userId': 7, 'id': 137, 'title': 'qui sit non', 'completed': False},
#  {'userId': 7,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'completed': False},
#  {'userId': 7,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'completed': True},
#  {'userId': 8,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'completed': True},
#  {'userId': 8,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'completed': True},
#  {'userId': 8,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'completed': False},
#  {'userId': 8,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'completed': False},
#  {'userId': 8,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'completed': False},
#  {'userId': 8,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'completed': True},
#  {'userId': 8,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'completed': True},
#  {'userId': 8,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'completed': False},
#  {'userId': 8,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'completed': False},
#  {'userId': 8,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'completed': False},
#  {'userId': 8,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'completed': True},
#  {'userId': 8,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'completed': False},
#  {'userId': 8,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'completed': False},
#  {'userId': 8, 'id': 154, 'title': 'rerum non ex sapiente', 'completed': True},
#  {'userId': 8,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'completed': True},
#  {'userId': 8,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'completed': True},
#  {'userId': 8,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'completed': True},
#  {'userId': 8,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'completed': False},
#  {'userId': 9,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'completed': True},
#  {'userId': 9,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'completed': True},
#  {'userId': 9,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'completed': False},
#  {'userId': 9,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'completed': False},
#  {'userId': 9,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'completed': False},
#  {'userId': 9,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'completed': False},
#  {'userId': 9,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'completed': False},
#  {'userId': 9,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'completed': True},
#  {'userId': 9,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'completed': False},
#  {'userId': 9,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'completed': True},
#  {'userId': 9,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'completed': False},
#  {'userId': 9,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'completed': False},
#  {'userId': 9, 'id': 174, 'title': 'similique aut quo', 'completed': False},
#  {'userId': 9,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'completed': True},
#  {'userId': 9,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'completed': False},
#  {'userId': 9,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'completed': True},
#  {'userId': 9,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'completed': True},
#  {'userId': 9,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'completed': True},
#  {'userId': 10,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'completed': False},
#  {'userId': 10,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'completed': True},
#  {'userId': 10,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'completed': True},
#  {'userId': 10,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'completed': False},
#  {'userId': 10,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'completed': False},
#  {'userId': 10,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'completed': False},
#  {'userId': 10,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'completed': False},
#  {'userId': 10, 'id': 188, 'title': 'vel non beatae est', 'completed': True},
#  {'userId': 10,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'completed': True},
#  {'userId': 10,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'completed': True},
#  {'userId': 10,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'completed': False},
#  {'userId': 10,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'completed': True},
#  {'userId': 10,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'completed': False},
#  {'userId': 10,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'completed': True},
#  {'userId': 10,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'completed': True},
#  {'userId': 10,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'completed': True},
#  {'userId': 10,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'completed': True},
#  {'userId': 10,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '17993615977',
#   'type': 'PushEvent',
#   'actor': {'id': 39209977,
#    'login': 'torokoid',
#    'display_login': 'torokoid',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/torokoid',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39209977?'},
#   'repo': {'id': 401697441,
#    'name': 'torokoid/access-test',
#    'url': 'https://api.github.com/repos/torokoid/access-test'},
#   'payload': {'push_id': 7938256149,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '507e63e6e611584a05bcadd2c2fe615ba16f401c',
#    'before': 'f83909efed67b93a6c393b9716781ecc08418ed9',
#    'commits': [{'sha': '507e63e6e611584a05bcadd2c2fe615ba16f401c',
#      'author': {'email': '39209977+torokoid@users.noreply.github.com',
#       'name': 'torokoid'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/torokoid/access-test/commits/507e63e6e611584a05bcadd2c2fe615ba16f401c'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z'},
#  {'id': '17993616002',
#   'type': 'PushEvent',
#   'actor': {'id': 7236757,
#    'login': 'ReedOnly',
#    'display_login': 'ReedOnly',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ReedOnly',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7236757?'},
#   'repo': {'id': 299604332,
#    'name': 'equinor/fusion-bmt',
#    'url': 'https://api.github.com/repos/equinor/fusion-bmt'},
#   'payload': {'push_id': 7938256152,
#    'size': 9,
#    'distinct_size': 0,
#    'ref': 'refs/heads/test',
#    'head': 'e9d603c31a66ce109b281c8d0bcc1345fee241ad',
#    'before': '72c7e8b93316f6752eecffae86707be78298bb29',
#    'commits': [{'sha': '63ffe728eaec2395042e8576c631f4c8ec136749',
#      'author': {'email': 'pewi@equinor.com', 'name': 'petterwildhagen'},
#      'message': 'Replaced making first participant facilitator with throwing error if facilitator not present',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/equinor/fusion-bmt/commits/63ffe728eaec2395042e8576c631f4c8ec136749'},
#     {'sha': 'd28b8e4d7d3a6050883a550fc5624adff50537a8',
#      'author': {'email': 'pewi@equinor.com', 'name': 'petterwildhagen'},
#      'message': 'Specify roles in bowtie_completion_date tests',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/equinor/fusion-bmt/commits/d28b8e4d7d3a6050883a550fc5624adff50537a8'},
#     {'sha': '60e436a1bae4ae9b5159da3f4ead4d3069d83629',
#      'author': {'email': 'pewi@equinor.com', 'name': 'petterwildhagen'},
#      'message': 'Specify roles in create evaluation tests',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/equinor/fusion-bmt/commits/60e436a1bae4ae9b5159da3f4ead4d3069d83629'},
#     {'sha': '0f1f77eb37fc6f9567c5731b7cbdd847241888a1',
#      'author': {'email': 'pewi@equinor.com', 'name': 'petterwildhagen'},
#      'message': 'Specify roles in constructor in evaluationSeed',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/equinor/fusion-bmt/commits/0f1f77eb37fc6f9567c5731b7cbdd847241888a1'},
#     {'sha': 'd344835fc162e2d5bc0f4ac07b7de946eb5309c5',
#      'author': {'email': 'pewi@equinor.com', 'name': 'petterwildhagen'},
#      'message': 'Specify roles in sample_seed.ts',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/equinor/fusion-bmt/commits/d344835fc162e2d5bc0f4ac07b7de946eb5309c5'},
#     {'sha': '5d9f1a7015a1a451fa22b7bd913319709771a4c4',
#      'author': {'email': 'pewi@equinor.com', 'name': 'petterwildhagen'},
#      'message': 'Merge pull request #625 from equinor/simplifyEvaluationSeed\n\nReplaced making first participant facilitator with throwing error if …',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/equinor/fusion-bmt/commits/5d9f1a7015a1a451fa22b7bd913319709771a4c4'},
#     {'sha': '6fa2b2770ec18708ea25b46d02c318c690168e94',
#      'author': {'email': 'krr@equinor.com', 'name': 'Kristian Reed'},
#      'message': 'Run Cypress tests in parallell in CI to speed up (#624)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/equinor/fusion-bmt/commits/6fa2b2770ec18708ea25b46d02c318c690168e94'},
#     {'sha': '5fc794bae7cf93f83c42f38cfb758d09ca085528',
#      'author': {'email': 'maito@equinor.com', 'name': 'Maia Tømmerbakk'},
#      'message': 'Add list of questions to each barrier',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/equinor/fusion-bmt/commits/5fc794bae7cf93f83c42f38cfb758d09ca085528'},
#     {'sha': 'e9d603c31a66ce109b281c8d0bcc1345fee241ad',
#      'author': {'email': 'pewi@equinor.com', 'name': 'petterwildhagen'},
#      'message': 'Remove default arg for role and progression from EvaluationSeed, place randomization of test data in test (#631)\n\n* Remove randomization from EvaluationSeed to test data creation in tests',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/equinor/fusion-bmt/commits/e9d603c31a66ce109b281c8d0bcc1345fee241ad'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z',
#   'org': {'id': 525862,
#    'login': 'equinor',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/equinor',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/525862?'}},
#  {'id': '17993615992',
#   'type': 'PushEvent',
#   'actor': {'id': 539462,
#    'login': 'enumag',
#    'display_login': 'enumag',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/enumag',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/539462?'},
#   'repo': {'id': 142838689,
#    'name': 'enumag/phpstorm-settings',
#    'url': 'https://api.github.com/repos/enumag/phpstorm-settings'},
#   'payload': {'push_id': 7938256156,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ccf9f0ded5918270896cdd39942685013803b980',
#    'before': '8724ebf8302c5bd12531c6c81c8f4753760dd356',
#    'commits': [{'sha': 'ccf9f0ded5918270896cdd39942685013803b980',
#      'author': {'email': 'enumag@gmail.com', 'name': 'Jáchym Toušek'},
#      'message': 'PS-2021.2 <enumag@enumag-HP-ProBook-450-G5 Update filetypes.xml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/enumag/phpstorm-settings/commits/ccf9f0ded5918270896cdd39942685013803b980'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z'},
#  {'id': '17993615964',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 392121990,
#    'name': 'ThatTimothy/testing-github-actions',
#    'url': 'https://api.github.com/repos/ThatTimothy/testing-github-actions'},
#   'payload': {'push_id': 7938256117,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a1a35ec7ff13676ad721311d4afcf6a12f2843f0',
#    'before': 'c8288ba3cd31b874324ff648d8334743152333e8',
#    'commits': [{'sha': 'a1a35ec7ff13676ad721311d4afcf6a12f2843f0',
#      'author': {'email': 'github-actions@github.com', 'name': 'Tester'},
#      'message': '09:15:44 2021-09-15',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ThatTimothy/testing-github-actions/commits/a1a35ec7ff13676ad721311d4afcf6a12f2843f0'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z'},
#  {'id': '17993615953',
#   'type': 'PushEvent',
#   'actor': {'id': 90753792,
#    'login': 'totobank',
#    'display_login': 'totobank',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/totobank',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90753792?'},
#   'repo': {'id': 406658281,
#    'name': 'totobank/images',
#    'url': 'https://api.github.com/repos/totobank/images'},
#   'payload': {'push_id': 7938256111,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '26313d94073777c35a0a4f494e8c94cb2bd29c06',
#    'before': '688245b062c5f803c1e03a7445b29e527f2299ce',
#    'commits': [{'sha': '26313d94073777c35a0a4f494e8c94cb2bd29c06',
#      'author': {'email': '90753792+totobank@users.noreply.github.com',
#       'name': 'totobank'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/totobank/images/commits/26313d94073777c35a0a4f494e8c94cb2bd29c06'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z'},
#  {'id': '17993615982',
#   'type': 'PushEvent',
#   'actor': {'id': 696855,
#    'login': 'vyazelenko',
#    'display_login': 'vyazelenko',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vyazelenko',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/696855?'},
#   'repo': {'id': 16621659,
#    'name': 'real-logic/aeron',
#    'url': 'https://api.github.com/repos/real-logic/aeron'},
#   'payload': {'push_id': 7938256021,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd885177e4db12c641e5d912b9e0735c3e0d26e44',
#    'before': '106359193a10cfb604a8b02bb6238028d72c9d89',
#    'commits': [{'sha': 'd885177e4db12c641e5d912b9e0735c3e0d26e44',
#      'author': {'email': '696855+vyazelenko@users.noreply.github.com',
#       'name': 'Dmitry Vyazelenko'},
#      'message': '[Java] Disable suppressed exceptions and creation of any kind of stack trace for AeronEvents.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/real-logic/aeron/commits/d885177e4db12c641e5d912b9e0735c3e0d26e44'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z',
#   'org': {'id': 5371471,
#    'login': 'real-logic',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/real-logic',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5371471?'}},
#  {'id': '17993615986',
#   'type': 'PushEvent',
#   'actor': {'id': 28552913,
#    'login': 'diggajupadhyay',
#    'display_login': 'diggajupadhyay',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/diggajupadhyay',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28552913?'},
#   'repo': {'id': 403517916,
#    'name': 'diggajupadhyay/InventorySystem',
#    'url': 'https://api.github.com/repos/diggajupadhyay/InventorySystem'},
#   'payload': {'push_id': 7938256131,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/experimental',
#    'head': 'b1002da78ae271a62195e925aa94042eecb22251',
#    'before': '51a601327ed1e6347b7e235e4aa5bb573524479b',
#    'commits': [{'sha': 'c903d8270eb56aacf35b4cb64ec7f3deae4e92ab',
#      'author': {'email': 'dcozupadhyay@gmail.com', 'name': 'Diggaj Upadhyay'},
#      'message': 'updated the readme on how to contribute to the project',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/diggajupadhyay/InventorySystem/commits/c903d8270eb56aacf35b4cb64ec7f3deae4e92ab'},
#     {'sha': 'b1002da78ae271a62195e925aa94042eecb22251',
#      'author': {'email': 'dcozupadhyay@gmail.com', 'name': 'Diggaj Upadhyay'},
#      'message': "Merge branch 'experimental' of https://github.com/diggajupadhyay/InventorySystem into experimental",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/diggajupadhyay/InventorySystem/commits/b1002da78ae271a62195e925aa94042eecb22251'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z'},
#  {'id': '17993615980',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 265094381,
#    'name': 'Lombiq/Testing-Toolbox',
#    'url': 'https://api.github.com/repos/Lombiq/Testing-Toolbox'},
#   'payload': {'push_id': 7938256158,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/issue/FINI-288',
#    'head': 'ba081e89f7da06ebbc1de7d0ca6ffba86b5b628b',
#    'before': 'ba081e89f7da06ebbc1de7d0ca6ffba86b5b628b',
#    'commits': []},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '17993615974',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 369002149,
#    'name': 'bryanwills/parcel',
#    'url': 'https://api.github.com/repos/bryanwills/parcel'},
#   'payload': {'action': 'opened',
#    'number': 31,
#    'pull_request': {'url': 'https://api.github.com/repos/bryanwills/parcel/pulls/31',
#     'id': 734375350,
#     'node_id': 'PR_kwDOFf6Gpc4rxa22',
#     'html_url': 'https://github.com/bryanwills/parcel/pull/31',
#     'diff_url': 'https://github.com/bryanwills/parcel/pull/31.diff',
#     'patch_url': 'https://github.com/bryanwills/parcel/pull/31.patch',
#     'issue_url': 'https://api.github.com/repos/bryanwills/parcel/issues/31',
#     'number': 31,
#     'state': 'open',
#     'locked': False,
#     'title': '[pull] v2 from parcel-bundler:v2',
#     'user': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'See Commits and Changes for more details.\n\n-----\nCreated by [<img src="https://prod.download/pull-18h-svg" valign="bottom"/> **pull[bot]**](https://github.com/wei/pull)\n\n_Can you help keep this open source service alive? **[💖 Please sponsor : )](https://prod.download/pull-pr-sponsor)**_',
#     'created_at': '2021-09-15T09:15:46Z',
#     'updated_at': '2021-09-15T09:15:46Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/bryanwills/parcel/pulls/31/commits',
#     'review_comments_url': 'https://api.github.com/repos/bryanwills/parcel/pulls/31/comments',
#     'review_comment_url': 'https://api.github.com/repos/bryanwills/parcel/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/bryanwills/parcel/issues/31/comments',
#     'statuses_url': 'https://api.github.com/repos/bryanwills/parcel/statuses/6f6759e5c2140aa8d7c3be70d56432258439ff19',
#     'head': {'label': 'parcel-bundler:v2',
#      'ref': 'v2',
#      'sha': '6f6759e5c2140aa8d7c3be70d56432258439ff19',
#      'user': {'login': 'parcel-bundler',
#       'id': 32607881,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMyNjA3ODgx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/32607881?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/parcel-bundler',
#       'html_url': 'https://github.com/parcel-bundler',
#       'followers_url': 'https://api.github.com/users/parcel-bundler/followers',
#       'following_url': 'https://api.github.com/users/parcel-bundler/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/parcel-bundler/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/parcel-bundler/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/parcel-bundler/subscriptions',
#       'organizations_url': 'https://api.github.com/users/parcel-bundler/orgs',
#       'repos_url': 'https://api.github.com/users/parcel-bundler/repos',
#       'events_url': 'https://api.github.com/users/parcel-bundler/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/parcel-bundler/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 99598595,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk5OTU5ODU5NQ==',
#       'name': 'parcel',
#       'full_name': 'parcel-bundler/parcel',
#       'private': False,
#       'owner': {'login': 'parcel-bundler',
#        'id': 32607881,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMyNjA3ODgx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/32607881?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/parcel-bundler',
#        'html_url': 'https://github.com/parcel-bundler',
#        'followers_url': 'https://api.github.com/users/parcel-bundler/followers',
#        'following_url': 'https://api.github.com/users/parcel-bundler/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/parcel-bundler/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/parcel-bundler/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/parcel-bundler/subscriptions',
#        'organizations_url': 'https://api.github.com/users/parcel-bundler/orgs',
#        'repos_url': 'https://api.github.com/users/parcel-bundler/repos',
#        'events_url': 'https://api.github.com/users/parcel-bundler/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/parcel-bundler/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/parcel-bundler/parcel',
#       'description': '📦🚀 Blazing fast, zero configuration web application bundler',
#       'fork': False,
#       'url': 'https://api.github.com/repos/parcel-bundler/parcel',
#       'forks_url': 'https://api.github.com/repos/parcel-bundler/parcel/forks',
#       'keys_url': 'https://api.github.com/repos/parcel-bundler/parcel/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/parcel-bundler/parcel/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/parcel-bundler/parcel/teams',
#       'hooks_url': 'https://api.github.com/repos/parcel-bundler/parcel/hooks',
#       'issue_events_url': 'https://api.github.com/repos/parcel-bundler/parcel/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/parcel-bundler/parcel/events',
#       'assignees_url': 'https://api.github.com/repos/parcel-bundler/parcel/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/parcel-bundler/parcel/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/parcel-bundler/parcel/tags',
#       'blobs_url': 'https://api.github.com/repos/parcel-bundler/parcel/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/parcel-bundler/parcel/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/parcel-bundler/parcel/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/parcel-bundler/parcel/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/parcel-bundler/parcel/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/parcel-bundler/parcel/languages',
#       'stargazers_url': 'https://api.github.com/repos/parcel-bundler/parcel/stargazers',
#       'contributors_url': 'https://api.github.com/repos/parcel-bundler/parcel/contributors',
#       'subscribers_url': 'https://api.github.com/repos/parcel-bundler/parcel/subscribers',
#       'subscription_url': 'https://api.github.com/repos/parcel-bundler/parcel/subscription',
#       'commits_url': 'https://api.github.com/repos/parcel-bundler/parcel/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/parcel-bundler/parcel/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/parcel-bundler/parcel/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/parcel-bundler/parcel/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/parcel-bundler/parcel/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/parcel-bundler/parcel/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/parcel-bundler/parcel/merges',
#       'archive_url': 'https://api.github.com/repos/parcel-bundler/parcel/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/parcel-bundler/parcel/downloads',
#       'issues_url': 'https://api.github.com/repos/parcel-bundler/parcel/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/parcel-bundler/parcel/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/parcel-bundler/parcel/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/parcel-bundler/parcel/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/parcel-bundler/parcel/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/parcel-bundler/parcel/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/parcel-bundler/parcel/deployments',
#       'created_at': '2017-08-07T16:36:47Z',
#       'updated_at': '2021-09-15T09:12:19Z',
#       'pushed_at': '2021-09-15T05:07:56Z',
#       'git_url': 'git://github.com/parcel-bundler/parcel.git',
#       'ssh_url': 'git@github.com:parcel-bundler/parcel.git',
#       'clone_url': 'https://github.com/parcel-bundler/parcel.git',
#       'svn_url': 'https://github.com/parcel-bundler/parcel',
#       'homepage': 'https://parceljs.org',
#       'size': 28027,
#       'stargazers_count': 38875,
#       'watchers_count': 38875,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1980,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 610,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'forks': 1980,
#       'open_issues': 610,
#       'watchers': 38875,
#       'default_branch': 'v2'}},
#     'base': {'label': 'bryanwills:v2',
#      'ref': 'v2',
#      'sha': '6dc8e68c496f61dd31de3f1d753f9bc976845f7a',
#      'user': {'login': 'bryanwills',
#       'id': 688756,
#       'node_id': 'MDQ6VXNlcjY4ODc1Ng==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/688756?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/bryanwills',
#       'html_url': 'https://github.com/bryanwills',
#       'followers_url': 'https://api.github.com/users/bryanwills/followers',
#       'following_url': 'https://api.github.com/users/bryanwills/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/bryanwills/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/bryanwills/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/bryanwills/subscriptions',
#       'organizations_url': 'https://api.github.com/users/bryanwills/orgs',
#       'repos_url': 'https://api.github.com/users/bryanwills/repos',
#       'events_url': 'https://api.github.com/users/bryanwills/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/bryanwills/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 369002149,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNjkwMDIxNDk=',
#       'name': 'parcel',
#       'full_name': 'bryanwills/parcel',
#       'private': False,
#       'owner': {'login': 'bryanwills',
#        'id': 688756,
#        'node_id': 'MDQ6VXNlcjY4ODc1Ng==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/688756?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/bryanwills',
#        'html_url': 'https://github.com/bryanwills',
#        'followers_url': 'https://api.github.com/users/bryanwills/followers',
#        'following_url': 'https://api.github.com/users/bryanwills/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/bryanwills/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/bryanwills/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/bryanwills/subscriptions',
#        'organizations_url': 'https://api.github.com/users/bryanwills/orgs',
#        'repos_url': 'https://api.github.com/users/bryanwills/repos',
#        'events_url': 'https://api.github.com/users/bryanwills/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/bryanwills/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/bryanwills/parcel',
#       'description': '📦🚀 Blazing fast, zero configuration web application bundler',
#       'fork': True,
#       'url': 'https://api.github.com/repos/bryanwills/parcel',
#       'forks_url': 'https://api.github.com/repos/bryanwills/parcel/forks',
#       'keys_url': 'https://api.github.com/repos/bryanwills/parcel/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/bryanwills/parcel/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/bryanwills/parcel/teams',
#       'hooks_url': 'https://api.github.com/repos/bryanwills/parcel/hooks',
#       'issue_events_url': 'https://api.github.com/repos/bryanwills/parcel/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/bryanwills/parcel/events',
#       'assignees_url': 'https://api.github.com/repos/bryanwills/parcel/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/bryanwills/parcel/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/bryanwills/parcel/tags',
#       'blobs_url': 'https://api.github.com/repos/bryanwills/parcel/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/bryanwills/parcel/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/bryanwills/parcel/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/bryanwills/parcel/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/bryanwills/parcel/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/bryanwills/parcel/languages',
#       'stargazers_url': 'https://api.github.com/repos/bryanwills/parcel/stargazers',
#       'contributors_url': 'https://api.github.com/repos/bryanwills/parcel/contributors',
#       'subscribers_url': 'https://api.github.com/repos/bryanwills/parcel/subscribers',
#       'subscription_url': 'https://api.github.com/repos/bryanwills/parcel/subscription',
#       'commits_url': 'https://api.github.com/repos/bryanwills/parcel/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/bryanwills/parcel/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/bryanwills/parcel/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/bryanwills/parcel/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/bryanwills/parcel/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/bryanwills/parcel/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/bryanwills/parcel/merges',
#       'archive_url': 'https://api.github.com/repos/bryanwills/parcel/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/bryanwills/parcel/downloads',
#       'issues_url': 'https://api.github.com/repos/bryanwills/parcel/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/bryanwills/parcel/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/bryanwills/parcel/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/bryanwills/parcel/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/bryanwills/parcel/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/bryanwills/parcel/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/bryanwills/parcel/deployments',
#       'created_at': '2021-05-19T21:10:33Z',
#       'updated_at': '2021-09-14T09:15:54Z',
#       'pushed_at': '2021-09-14T09:15:50Z',
#       'git_url': 'git://github.com/bryanwills/parcel.git',
#       'ssh_url': 'git@github.com:bryanwills/parcel.git',
#       'clone_url': 'https://github.com/bryanwills/parcel.git',
#       'svn_url': 'https://github.com/bryanwills/parcel',
#       'homepage': 'https://parceljs.org',
#       'size': 27076,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'v2'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/bryanwills/parcel/pulls/31'},
#      'html': {'href': 'https://github.com/bryanwills/parcel/pull/31'},
#      'issue': {'href': 'https://api.github.com/repos/bryanwills/parcel/issues/31'},
#      'comments': {'href': 'https://api.github.com/repos/bryanwills/parcel/issues/31/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/bryanwills/parcel/pulls/31/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/bryanwills/parcel/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/bryanwills/parcel/pulls/31/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/bryanwills/parcel/statuses/6f6759e5c2140aa8d7c3be70d56432258439ff19'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 79,
#     'deletions': 81,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z'},
#  {'id': '17993615984',
#   'type': 'ForkEvent',
#   'actor': {'id': 71380245,
#    'login': 'tualgfhite',
#    'display_login': 'tualgfhite',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tualgfhite',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71380245?'},
#   'repo': {'id': 389956496,
#    'name': 'cheerss/CrossFormer',
#    'url': 'https://api.github.com/repos/cheerss/CrossFormer'},
#   'payload': {'forkee': {'id': 406692040,
#     'node_id': 'MDEwOlJlcG9zaXRvcnk0MDY2OTIwNDA=',
#     'name': 'CrossFormer',
#     'full_name': 'tualgfhite/CrossFormer',
#     'private': False,
#     'owner': {'login': 'tualgfhite',
#      'id': 71380245,
#      'node_id': 'MDQ6VXNlcjcxMzgwMjQ1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/71380245?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tualgfhite',
#      'html_url': 'https://github.com/tualgfhite',
#      'followers_url': 'https://api.github.com/users/tualgfhite/followers',
#      'following_url': 'https://api.github.com/users/tualgfhite/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tualgfhite/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tualgfhite/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tualgfhite/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tualgfhite/orgs',
#      'repos_url': 'https://api.github.com/users/tualgfhite/repos',
#      'events_url': 'https://api.github.com/users/tualgfhite/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tualgfhite/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/tualgfhite/CrossFormer',
#     'description': 'The official code for the paper: https://arxiv.org/pdf/2108.00154.pdf',
#     'fork': True,
#     'url': 'https://api.github.com/repos/tualgfhite/CrossFormer',
#     'forks_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/forks',
#     'keys_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/teams',
#     'hooks_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/hooks',
#     'issue_events_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/events',
#     'assignees_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/tags',
#     'blobs_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/languages',
#     'stargazers_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/stargazers',
#     'contributors_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/contributors',
#     'subscribers_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/subscribers',
#     'subscription_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/subscription',
#     'commits_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/merges',
#     'archive_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/downloads',
#     'issues_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/tualgfhite/CrossFormer/deployments',
#     'created_at': '2021-09-15T09:15:46Z',
#     'updated_at': '2021-09-15T06:26:38Z',
#     'pushed_at': '2021-08-16T02:34:21Z',
#     'git_url': 'git://github.com/tualgfhite/CrossFormer.git',
#     'ssh_url': 'git@github.com:tualgfhite/CrossFormer.git',
#     'clone_url': 'https://github.com/tualgfhite/CrossFormer.git',
#     'svn_url': 'https://github.com/tualgfhite/CrossFormer',
#     'homepage': '',
#     'size': 3058,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z'},
#  {'id': '17993615963',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 17418390,
#    'login': 'Maling1255',
#    'display_login': 'Maling1255',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Maling1255',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17418390?'},
#   'repo': {'id': 272141550,
#    'name': 'MeetYouDevs/cocoapods-imy-bin',
#    'url': 'https://api.github.com/repos/MeetYouDevs/cocoapods-imy-bin'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/MeetYouDevs/cocoapods-imy-bin/issues/180',
#     'repository_url': 'https://api.github.com/repos/MeetYouDevs/cocoapods-imy-bin',
#     'labels_url': 'https://api.github.com/repos/MeetYouDevs/cocoapods-imy-bin/issues/180/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/MeetYouDevs/cocoapods-imy-bin/issues/180/comments',
#     'events_url': 'https://api.github.com/repos/MeetYouDevs/cocoapods-imy-bin/issues/180/events',
#     'html_url': 'https://github.com/MeetYouDevs/cocoapods-imy-bin/issues/180',
#     'id': 988963951,
#     'node_id': 'MDU6SXNzdWU5ODg5NjM5NTE=',
#     'number': 180,
#     'title': '制作完成没有资源文件',
#     'user': {'login': 'Maling1255',
#      'id': 17418390,
#      'node_id': 'MDQ6VXNlcjE3NDE4Mzkw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/17418390?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Maling1255',
#      'html_url': 'https://github.com/Maling1255',
#      'followers_url': 'https://api.github.com/users/Maling1255/followers',
#      'following_url': 'https://api.github.com/users/Maling1255/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Maling1255/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Maling1255/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Maling1255/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Maling1255/orgs',
#      'repos_url': 'https://api.github.com/users/Maling1255/repos',
#      'events_url': 'https://api.github.com/users/Maling1255/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Maling1255/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 8,
#     'created_at': '2021-09-06T09:20:52Z',
#     'updated_at': '2021-09-15T09:15:46Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': 'MJRefresh, SVProgressHUD制作完成的没有资源图片bundle,有.a 和头文件， 其他的库只要有bundle也都没有bundle，但是都是制作成功的',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/MeetYouDevs/cocoapods-imy-bin/issues/comments/919845952',
#     'html_url': 'https://github.com/MeetYouDevs/cocoapods-imy-bin/issues/180#issuecomment-919845952',
#     'issue_url': 'https://api.github.com/repos/MeetYouDevs/cocoapods-imy-bin/issues/180',
#     'id': 919845952,
#     'node_id': 'IC_kwDOEDiM7s4207xA',
#     'user': {'login': 'Maling1255',
#      'id': 17418390,
#      'node_id': 'MDQ6VXNlcjE3NDE4Mzkw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/17418390?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Maling1255',
#      'html_url': 'https://github.com/Maling1255',
#      'followers_url': 'https://api.github.com/users/Maling1255/followers',
#      'following_url': 'https://api.github.com/users/Maling1255/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Maling1255/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Maling1255/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Maling1255/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Maling1255/orgs',
#      'repos_url': 'https://api.github.com/users/Maling1255/repos',
#      'events_url': 'https://api.github.com/users/Maling1255/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Maling1255/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-09-15T09:15:46Z',
#     'updated_at': '2021-09-15T09:15:46Z',
#     'author_association': 'NONE',
#     'body': '> > > 其实 binary.podspec.json 文件里面是有 Resources 的路径指向的，但因为生成二进制的时候，没有将对应的资源 copy 成功，所以会导致这个问题。我不太懂 ruby 代码，所以就做了这个处理\r\n> > \r\n> > \r\n> > > 我说错了，应该是默认所有二进制包都有Resources 文件夹\r\n> > > 搜索以下代码，删除就好\r\n> > > if @spec.attributes_hash.keys.include?("resources")\r\n> > \r\n> > \r\n> > 修改了源码 怎么使用源码，这个不会弄， 老哥能给点指点吗\r\n> \r\n> 额，谷歌一下啊\r\n> 修改下版本号，cd 根目录\r\n> gem build cocoapods-imy-bin\r\n> gem install cocoapods-imy-bin\r\n\r\n好的  感谢呀👍',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z',
#   'org': {'id': 34014425,
#    'login': 'MeetYouDevs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/MeetYouDevs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34014425?'}},
#  {'id': '17993615935',
#   'type': 'PushEvent',
#   'actor': {'id': 52290251,
#    'login': 'botcopado',
#    'display_login': 'botcopado',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/botcopado',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52290251?'},
#   'repo': {'id': 406691869,
#    'name': 'botcopado/moeldv_SWJW0WW2',
#    'url': 'https://api.github.com/repos/botcopado/moeldv_SWJW0WW2'},
#   'payload': {'push_id': 7938256109,
#    'size': 1,
#    'distinct_size': 0,
#    'ref': 'refs/heads/staging',
#    'head': 'ea879dd34670a86977f3d1238f1c5a848ab3a59b',
#    'before': '93d1fb4fb6e7902ae9084f0e4a4cdead533aeb7e',
#    'commits': [{'sha': 'ea879dd34670a86977f3d1238f1c5a848ab3a59b',
#      'author': {'email': 'qa-automation@copado.com', 'name': 'QA Automation'},
#      'message': 'US-0090851 Destrutive message',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/botcopado/moeldv_SWJW0WW2/commits/ea879dd34670a86977f3d1238f1c5a848ab3a59b'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z'},
#  {'id': '17993615981',
#   'type': 'CreateEvent',
#   'actor': {'id': 90719530,
#    'login': 'SzDorian',
#    'display_login': 'SzDorian',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SzDorian',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90719530?'},
#   'repo': {'id': 406692039,
#    'name': 'SzDorian/kollazs',
#    'url': 'https://api.github.com/repos/SzDorian/kollazs'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z'},
#  {'id': '17993615956',
#   'type': 'PushEvent',
#   'actor': {'id': 16876177,
#    'login': 'Typelias',
#    'display_login': 'Typelias',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Typelias',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16876177?'},
#   'repo': {'id': 406690488,
#    'name': 'Typelias/Meeting-Mockup',
#    'url': 'https://api.github.com/repos/Typelias/Meeting-Mockup'},
#   'payload': {'push_id': 7938256067,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'bfd423fbe0caaf60ecfb5a78fb6aaed3e9a5eb87',
#    'before': '1c7e00fff8d5fa7636c6187246c384669c865477',
#    'commits': [{'sha': 'bfd423fbe0caaf60ecfb5a78fb6aaed3e9a5eb87',
#      'author': {'email': '98ille@gmail.com', 'name': 'typelias'},
#      'message': 'Init',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Typelias/Meeting-Mockup/commits/bfd423fbe0caaf60ecfb5a78fb6aaed3e9a5eb87'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z'},
#  {'id': '17993615952',
#   'type': 'PushEvent',
#   'actor': {'id': 40821357,
#    'login': 'anna-won',
#    'display_login': 'anna-won',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anna-won',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40821357?'},
#   'repo': {'id': 406171703,
#    'name': 'anna-won/pod-test',
#    'url': 'https://api.github.com/repos/anna-won/pod-test'},
#   'payload': {'push_id': 7938256112,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '4577d5325b64381c9e8be296c3e20cf9d87cf7b4',
#    'before': 'cd5455849e717233ee3cc20dce54b77e433ed878',
#    'commits': [{'sha': '4577d5325b64381c9e8be296c3e20cf9d87cf7b4',
#      'author': {'email': '40821357+anna-won@users.noreply.github.com',
#       'name': 'anna-won'},
#      'message': 'Update swift.yml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/anna-won/pod-test/commits/4577d5325b64381c9e8be296c3e20cf9d87cf7b4'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z'},
#  {'id': '17993615938',
#   'type': 'PushEvent',
#   'actor': {'id': 79471853,
#    'login': 'Sa6aTeur',
#    'display_login': 'Sa6aTeur',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Sa6aTeur',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79471853?'},
#   'repo': {'id': 404673787,
#    'name': 'Sa6aTeur/API-console',
#    'url': 'https://api.github.com/repos/Sa6aTeur/API-console'},
#   'payload': {'push_id': 7938256087,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '0686926d4ee655bbb8a03c6e1b1ee806bf8f9e72',
#    'before': 'fce5a547b7e67c42c778a3bb45d88f4bd0d87c9b',
#    'commits': [{'sha': '0686926d4ee655bbb8a03c6e1b1ee806bf8f9e72',
#      'author': {'email': 'yuri.lysenko@bonrepublic.com',
#       'name': 'yuri.lysenko'},
#      'message': 'Updates',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Sa6aTeur/API-console/commits/0686926d4ee655bbb8a03c6e1b1ee806bf8f9e72'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z'},
#  {'id': '17993615937',
#   'type': 'CreateEvent',
#   'actor': {'id': 83448519,
#    'login': 'imorenov94',
#    'display_login': 'imorenov94',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/imorenov94',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83448519?'},
#   'repo': {'id': 290137906,
#    'name': 'Haulmont/jmix-ui-tests',
#    'url': 'https://api.github.com/repos/Haulmont/jmix-ui-tests'},
#   'payload': {'ref': 'feature/ui-test-email',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Jmix Backoffice UI test suite',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z',
#   'org': {'id': 4005527,
#    'login': 'Haulmont',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Haulmont',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4005527?'}},
#  {'id': '17993615922',
#   'type': 'PushEvent',
#   'actor': {'id': 25057099,
#    'login': 'jaysolanki46',
#    'display_login': 'jaysolanki46',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jaysolanki46',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25057099?'},
#   'repo': {'id': 381911412,
#    'name': 'jaysolanki46/Skyzer',
#    'url': 'https://api.github.com/repos/jaysolanki46/Skyzer'},
#   'payload': {'push_id': 7938256116,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '513e98bfa69644e508c6e407346bdc69cbb22d25',
#    'before': 'cb5a9252689be321e53f213f5cdfcbff0e0e7a17',
#    'commits': [{'sha': '513e98bfa69644e508c6e407346bdc69cbb22d25',
#      'author': {'email': 'Jay.Solanki@nz.skyzer.local', 'name': 'Jay Solanki'},
#      'message': 'Contact designed',
#      'distinct': True,
# ...
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/secondmind-labs/trieste/pulls/346/commits',
#     'review_comments_url': 'https://api.github.com/repos/secondmind-labs/trieste/pulls/346/comments',
#     'review_comment_url': 'https://api.github.com/repos/secondmind-labs/trieste/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/secondmind-labs/trieste/issues/346/comments',
#     'statuses_url': 'https://api.github.com/repos/secondmind-labs/trieste/statuses/ee8fdb3acc8af8925cd3a97f87754077f8870c65',
#     'head': {'label': 'apaleyes:ask-tell',
#      'ref': 'ask-tell',
#      'sha': 'ee8fdb3acc8af8925cd3a97f87754077f8870c65',
#      'user': {'login': 'apaleyes',
#       'id': 2852301,
#       'node_id': 'MDQ6VXNlcjI4NTIzMDE=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/2852301?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/apaleyes',
#       'html_url': 'https://github.com/apaleyes',
#       'followers_url': 'https://api.github.com/users/apaleyes/followers',
#       'following_url': 'https://api.github.com/users/apaleyes/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/apaleyes/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/apaleyes/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/apaleyes/subscriptions',
#       'organizations_url': 'https://api.github.com/users/apaleyes/orgs',
#       'repos_url': 'https://api.github.com/users/apaleyes/repos',
#       'events_url': 'https://api.github.com/users/apaleyes/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/apaleyes/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 404656838,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk0MDQ2NTY4Mzg=',
#       'name': 'trieste',
#       'full_name': 'apaleyes/trieste',
#       'private': False,
#       'owner': {'login': 'apaleyes',
#        'id': 2852301,
#        'node_id': 'MDQ6VXNlcjI4NTIzMDE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/2852301?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/apaleyes',
#        'html_url': 'https://github.com/apaleyes',
#        'followers_url': 'https://api.github.com/users/apaleyes/followers',
#        'following_url': 'https://api.github.com/users/apaleyes/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/apaleyes/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/apaleyes/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/apaleyes/subscriptions',
#        'organizations_url': 'https://api.github.com/users/apaleyes/orgs',
#        'repos_url': 'https://api.github.com/users/apaleyes/repos',
#        'events_url': 'https://api.github.com/users/apaleyes/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/apaleyes/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/apaleyes/trieste',
#       'description': 'A Bayesian optimization toolbox built on TensorFlow',
#       'fork': True,
#       'url': 'https://api.github.com/repos/apaleyes/trieste',
#       'forks_url': 'https://api.github.com/repos/apaleyes/trieste/forks',
#       'keys_url': 'https://api.github.com/repos/apaleyes/trieste/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/apaleyes/trieste/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/apaleyes/trieste/teams',
#       'hooks_url': 'https://api.github.com/repos/apaleyes/trieste/hooks',
#       'issue_events_url': 'https://api.github.com/repos/apaleyes/trieste/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/apaleyes/trieste/events',
#       'assignees_url': 'https://api.github.com/repos/apaleyes/trieste/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/apaleyes/trieste/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/apaleyes/trieste/tags',
#       'blobs_url': 'https://api.github.com/repos/apaleyes/trieste/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/apaleyes/trieste/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/apaleyes/trieste/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/apaleyes/trieste/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/apaleyes/trieste/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/apaleyes/trieste/languages',
#       'stargazers_url': 'https://api.github.com/repos/apaleyes/trieste/stargazers',
#       'contributors_url': 'https://api.github.com/repos/apaleyes/trieste/contributors',
#       'subscribers_url': 'https://api.github.com/repos/apaleyes/trieste/subscribers',
#       'subscription_url': 'https://api.github.com/repos/apaleyes/trieste/subscription',
#       'commits_url': 'https://api.github.com/repos/apaleyes/trieste/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/apaleyes/trieste/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/apaleyes/trieste/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/apaleyes/trieste/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/apaleyes/trieste/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/apaleyes/trieste/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/apaleyes/trieste/merges',
#       'archive_url': 'https://api.github.com/repos/apaleyes/trieste/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/apaleyes/trieste/downloads',
#       'issues_url': 'https://api.github.com/repos/apaleyes/trieste/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/apaleyes/trieste/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/apaleyes/trieste/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/apaleyes/trieste/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/apaleyes/trieste/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/apaleyes/trieste/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/apaleyes/trieste/deployments',
#       'created_at': '2021-09-09T09:10:52Z',
#       'updated_at': '2021-09-09T09:10:54Z',
#       'pushed_at': '2021-09-13T14:56:20Z',
#       'git_url': 'git://github.com/apaleyes/trieste.git',
#       'ssh_url': 'git@github.com:apaleyes/trieste.git',
#       'clone_url': 'https://github.com/apaleyes/trieste.git',
#       'svn_url': 'https://github.com/apaleyes/trieste',
#       'homepage': None,
#       'size': 11441,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'develop'}},
#     'base': {'label': 'secondmind-labs:develop',
#      'ref': 'develop',
#      'sha': '883ffd916b790631811c29166b9d1190202dd940',
#      'user': {'login': 'secondmind-labs',
#       'id': 66955765,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY2OTU1NzY1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/66955765?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/secondmind-labs',
#       'html_url': 'https://github.com/secondmind-labs',
#       'followers_url': 'https://api.github.com/users/secondmind-labs/followers',
#       'following_url': 'https://api.github.com/users/secondmind-labs/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/secondmind-labs/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/secondmind-labs/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/secondmind-labs/subscriptions',
#       'organizations_url': 'https://api.github.com/users/secondmind-labs/orgs',
#       'repos_url': 'https://api.github.com/users/secondmind-labs/repos',
#       'events_url': 'https://api.github.com/users/secondmind-labs/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/secondmind-labs/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 301446732,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMDE0NDY3MzI=',
#       'name': 'trieste',
#       'full_name': 'secondmind-labs/trieste',
#       'private': False,
#       'owner': {'login': 'secondmind-labs',
#        'id': 66955765,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY2OTU1NzY1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/66955765?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/secondmind-labs',
#        'html_url': 'https://github.com/secondmind-labs',
#        'followers_url': 'https://api.github.com/users/secondmind-labs/followers',
#        'following_url': 'https://api.github.com/users/secondmind-labs/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/secondmind-labs/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/secondmind-labs/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/secondmind-labs/subscriptions',
#        'organizations_url': 'https://api.github.com/users/secondmind-labs/orgs',
#        'repos_url': 'https://api.github.com/users/secondmind-labs/repos',
#        'events_url': 'https://api.github.com/users/secondmind-labs/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/secondmind-labs/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/secondmind-labs/trieste',
#       'description': 'A Bayesian optimization toolbox built on TensorFlow',
#       'fork': False,
#       'url': 'https://api.github.com/repos/secondmind-labs/trieste',
#       'forks_url': 'https://api.github.com/repos/secondmind-labs/trieste/forks',
#       'keys_url': 'https://api.github.com/repos/secondmind-labs/trieste/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/secondmind-labs/trieste/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/secondmind-labs/trieste/teams',
#       'hooks_url': 'https://api.github.com/repos/secondmind-labs/trieste/hooks',
#       'issue_events_url': 'https://api.github.com/repos/secondmind-labs/trieste/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/secondmind-labs/trieste/events',
#       'assignees_url': 'https://api.github.com/repos/secondmind-labs/trieste/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/secondmind-labs/trieste/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/secondmind-labs/trieste/tags',
#       'blobs_url': 'https://api.github.com/repos/secondmind-labs/trieste/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/secondmind-labs/trieste/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/secondmind-labs/trieste/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/secondmind-labs/trieste/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/secondmind-labs/trieste/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/secondmind-labs/trieste/languages',
#       'stargazers_url': 'https://api.github.com/repos/secondmind-labs/trieste/stargazers',
#       'contributors_url': 'https://api.github.com/repos/secondmind-labs/trieste/contributors',
#       'subscribers_url': 'https://api.github.com/repos/secondmind-labs/trieste/subscribers',
#       'subscription_url': 'https://api.github.com/repos/secondmind-labs/trieste/subscription',
#       'commits_url': 'https://api.github.com/repos/secondmind-labs/trieste/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/secondmind-labs/trieste/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/secondmind-labs/trieste/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/secondmind-labs/trieste/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/secondmind-labs/trieste/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/secondmind-labs/trieste/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/secondmind-labs/trieste/merges',
#       'archive_url': 'https://api.github.com/repos/secondmind-labs/trieste/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/secondmind-labs/trieste/downloads',
#       'issues_url': 'https://api.github.com/repos/secondmind-labs/trieste/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/secondmind-labs/trieste/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/secondmind-labs/trieste/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/secondmind-labs/trieste/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/secondmind-labs/trieste/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/secondmind-labs/trieste/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/secondmind-labs/trieste/deployments',
#       'created_at': '2020-10-05T15:01:23Z',
#       'updated_at': '2021-09-14T16:31:51Z',
#       'pushed_at': '2021-09-15T08:38:53Z',
#       'git_url': 'git://github.com/secondmind-labs/trieste.git',
#       'ssh_url': 'git@github.com:secondmind-labs/trieste.git',
#       'clone_url': 'https://github.com/secondmind-labs/trieste.git',
#       'svn_url': 'https://github.com/secondmind-labs/trieste',
#       'homepage': None,
#       'size': 11479,
#       'stargazers_count': 85,
#       'watchers_count': 85,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': True,
#       'forks_count': 20,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 71,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'forks': 20,
#       'open_issues': 71,
#       'watchers': 85,
#       'default_branch': 'develop'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/secondmind-labs/trieste/pulls/346'},
#      'html': {'href': 'https://github.com/secondmind-labs/trieste/pull/346'},
#      'issue': {'href': 'https://api.github.com/repos/secondmind-labs/trieste/issues/346'},
#      'comments': {'href': 'https://api.github.com/repos/secondmind-labs/trieste/issues/346/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/secondmind-labs/trieste/pulls/346/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/secondmind-labs/trieste/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/secondmind-labs/trieste/pulls/346/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/secondmind-labs/trieste/statuses/ee8fdb3acc8af8925cd3a97f87754077f8870c65'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2021-09-15T09:15:46Z',
#   'org': {'id': 66955765,
#    'login': 'secondmind-labs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/secondmind-labs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66955765?'}}]

# %%
pd.DataFrame(response.json())
# Out:
#              id                           type  \
# 0   17993615977                      PushEvent
# 1   17993616002                      PushEvent
# 2   17993615992                      PushEvent
# 3   17993615964                      PushEvent
# 4   17993615953                      PushEvent
# 5   17993615982                      PushEvent
# 6   17993615986                      PushEvent
# 7   17993615980                      PushEvent
# 8   17993615974               PullRequestEvent
# 9   17993615984                      ForkEvent
# 10  17993615963              IssueCommentEvent
# 11  17993615935                      PushEvent
# 12  17993615981                    CreateEvent
# 13  17993615956                      PushEvent
# 14  17993615952                      PushEvent
# 15  17993615938                      PushEvent
# 16  17993615937                    CreateEvent
# 17  17993615922                      PushEvent
# 18  17993615930                      PushEvent
# 19  17993615905  PullRequestReviewCommentEvent
# 20  17993615921                    CreateEvent
# 21  17993615919                      PushEvent
# 22  17993615860                     WatchEvent
# 23  17993615857                    CreateEvent
# 24  17993615869                      PushEvent
# 25  17993615851                    CreateEvent
# 26  17993615888                      PushEvent
# 27  17993615855                    DeleteEvent
# 28  17993615768                      PushEvent
# 29  17993615829         PullRequestReviewEvent
#
#                                                 actor  \
# 0   {'id': 39209977, 'login': 'torokoid', 'display...
# 1   {'id': 7236757, 'login': 'ReedOnly', 'display_...
# 2   {'id': 539462, 'login': 'enumag', 'display_log...
# 3   {'id': 41898282, 'login': 'github-actions[bot]...
# 4   {'id': 90753792, 'login': 'totobank', 'display...
# 5   {'id': 696855, 'login': 'vyazelenko', 'display...
# 6   {'id': 28552913, 'login': 'diggajupadhyay', 'd...
# 7   {'id': 8517910, 'login': 'LombiqBot', 'display...
# 8   {'id': 39814207, 'login': 'pull[bot]', 'displa...
# 9   {'id': 71380245, 'login': 'tualgfhite', 'displ...
# 10  {'id': 17418390, 'login': 'Maling1255', 'displ...
# 11  {'id': 52290251, 'login': 'botcopado', 'displa...
# 12  {'id': 90719530, 'login': 'SzDorian', 'display...
# 13  {'id': 16876177, 'login': 'Typelias', 'display...
# 14  {'id': 40821357, 'login': 'anna-won', 'display...
# 15  {'id': 79471853, 'login': 'Sa6aTeur', 'display...
# 16  {'id': 83448519, 'login': 'imorenov94', 'displ...
# 17  {'id': 25057099, 'login': 'jaysolanki46', 'dis...
# 18  {'id': 90758938, 'login': 'codeticks', 'displa...
# 19  {'id': 2852301, 'login': 'apaleyes', 'display_...
# 20  {'id': 79159422, 'login': 'Akanksha-2911', 'di...
# 21  {'id': 60663418, 'login': 'petr-hlavnicka560',...
# 22  {'id': 32362010, 'login': 'robinvandenb', 'dis...
# 23  {'id': 90759162, 'login': 'Kiskuki', 'display_...
# 24  {'id': 87927395, 'login': 'pczh2010', 'display...
# 25  {'id': 90752043, 'login': 'jayesh678', 'displa...
# 26  {'id': 61824089, 'login': 'CarlosFora', 'displ...
# 27  {'id': 241593, 'login': 'adunstan', 'display_l...
# 28  {'id': 20429432, 'login': 'zyq1569', 'display_...
# 29  {'id': 2852301, 'login': 'apaleyes', 'display_...
#
#                                                  repo  \
# 0   {'id': 401697441, 'name': 'torokoid/access-tes...
# 1   {'id': 299604332, 'name': 'equinor/fusion-bmt'...
# 2   {'id': 142838689, 'name': 'enumag/phpstorm-set...
# 3   {'id': 392121990, 'name': 'ThatTimothy/testing...
# 4   {'id': 406658281, 'name': 'totobank/images', '...
# 5   {'id': 16621659, 'name': 'real-logic/aeron', '...
# 6   {'id': 403517916, 'name': 'diggajupadhyay/Inve...
# 7   {'id': 265094381, 'name': 'Lombiq/Testing-Tool...
# 8   {'id': 369002149, 'name': 'bryanwills/parcel',...
# 9   {'id': 389956496, 'name': 'cheerss/CrossFormer...
# 10  {'id': 272141550, 'name': 'MeetYouDevs/cocoapo...
# 11  {'id': 406691869, 'name': 'botcopado/moeldv_SW...
# 12  {'id': 406692039, 'name': 'SzDorian/kollazs', ...
# 13  {'id': 406690488, 'name': 'Typelias/Meeting-Mo...
# 14  {'id': 406171703, 'name': 'anna-won/pod-test',...
# 15  {'id': 404673787, 'name': 'Sa6aTeur/API-consol...
# 16  {'id': 290137906, 'name': 'Haulmont/jmix-ui-te...
# 17  {'id': 381911412, 'name': 'jaysolanki46/Skyzer...
# 18  {'id': 406689343, 'name': 'codeticks/It-starts...
# 19  {'id': 301446732, 'name': 'secondmind-labs/tri...
# 20  {'id': 406692033, 'name': 'Akanksha-2911/My-Gi...
# 21  {'id': 370996784, 'name': 'petr-hlavnicka560/r...
# 22  {'id': 74020203, 'name': 'thibmaek/bpost', 'ur...
# 23  {'id': 406692038, 'name': 'Kiskuki/kollazs', '...
# 24  {'id': 405701905, 'name': 'pczh2010/cf2dns', '...
# 25  {'id': 406692032, 'name': 'jayesh678/thesmalle...
# 26  {'id': 399395147, 'name': 'borgarpa/HRNet-Sema...
# 27  {'id': 381093067, 'name': 'adunstan/postgres-n...
# 28  {'id': 328524448, 'name': 'zyq1569/OpenWord', ...
# 29  {'id': 301446732, 'name': 'secondmind-labs/tri...
#
#                                               payload  public  \
# 0   {'push_id': 7938256149, 'size': 1, 'distinct_s...    True
# 1   {'push_id': 7938256152, 'size': 9, 'distinct_s...    True
# 2   {'push_id': 7938256156, 'size': 1, 'distinct_s...    True
# 3   {'push_id': 7938256117, 'size': 1, 'distinct_s...    True
# 4   {'push_id': 7938256111, 'size': 1, 'distinct_s...    True
# 5   {'push_id': 7938256021, 'size': 1, 'distinct_s...    True
# 6   {'push_id': 7938256131, 'size': 2, 'distinct_s...    True
# 7   {'push_id': 7938256158, 'size': 0, 'distinct_s...    True
# 8   {'action': 'opened', 'number': 31, 'pull_reque...    True
# 9   {'forkee': {'id': 406692040, 'node_id': 'MDEwO...    True
# 10  {'action': 'created', 'issue': {'url': 'https:...    True
# 11  {'push_id': 7938256109, 'size': 1, 'distinct_s...    True
# 12  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 13  {'push_id': 7938256067, 'size': 1, 'distinct_s...    True
# 14  {'push_id': 7938256112, 'size': 1, 'distinct_s...    True
# 15  {'push_id': 7938256087, 'size': 1, 'distinct_s...    True
# 16  {'ref': 'feature/ui-test-email', 'ref_type': '...    True
# 17  {'push_id': 7938256116, 'size': 1, 'distinct_s...    True
# 18  {'push_id': 7938256126, 'size': 1, 'distinct_s...    True
# 19  {'action': 'created', 'comment': {'url': 'http...    True
# 20  {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 21  {'push_id': 7938256089, 'size': 1, 'distinct_s...    True
# 22                              {'action': 'started'}    True
# 23  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 24  {'push_id': 7938256080, 'size': 1, 'distinct_s...    True
# 25  {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 26  {'push_id': 7938256076, 'size': 1, 'distinct_s...    True
# 27  {'ref': 'newdef-1631696402', 'ref_type': 'bran...    True
# 28  {'push_id': 7938256033, 'size': 1, 'distinct_s...    True
# 29  {'action': 'created', 'review': {'id': 7548698...    True
#
#               created_at                                                org
# 0   2021-09-15T09:15:46Z                                                NaN
# 1   2021-09-15T09:15:46Z  {'id': 525862, 'login': 'equinor', 'gravatar_i...
# 2   2021-09-15T09:15:46Z                                                NaN
# 3   2021-09-15T09:15:46Z                                                NaN
# 4   2021-09-15T09:15:46Z                                                NaN
# 5   2021-09-15T09:15:46Z  {'id': 5371471, 'login': 'real-logic', 'gravat...
# 6   2021-09-15T09:15:46Z                                                NaN
# 7   2021-09-15T09:15:46Z  {'id': 8158177, 'login': 'Lombiq', 'gravatar_i...
# 8   2021-09-15T09:15:46Z                                                NaN
# 9   2021-09-15T09:15:46Z                                                NaN
# 10  2021-09-15T09:15:46Z  {'id': 34014425, 'login': 'MeetYouDevs', 'grav...
# 11  2021-09-15T09:15:46Z                                                NaN
# 12  2021-09-15T09:15:46Z                                                NaN
# 13  2021-09-15T09:15:46Z                                                NaN
# 14  2021-09-15T09:15:46Z                                                NaN
# 15  2021-09-15T09:15:46Z                                                NaN
# 16  2021-09-15T09:15:46Z  {'id': 4005527, 'login': 'Haulmont', 'gravatar...
# 17  2021-09-15T09:15:46Z                                                NaN
# 18  2021-09-15T09:15:46Z                                                NaN
# 19  2021-09-15T09:15:45Z  {'id': 66955765, 'login': 'secondmind-labs', '...
# 20  2021-09-15T09:15:46Z                                                NaN
# 21  2021-09-15T09:15:46Z                                                NaN
# 22  2021-09-15T09:15:46Z                                                NaN
# 23  2021-09-15T09:15:46Z                                                NaN
# 24  2021-09-15T09:15:46Z                                                NaN
# 25  2021-09-15T09:15:46Z                                                NaN
# 26  2021-09-15T09:15:46Z                                                NaN
# 27  2021-09-15T09:15:46Z                                                NaN
# 28  2021-09-15T09:15:45Z                                                NaN
# 29  2021-09-15T09:15:46Z  {'id': 66955765, 'login': 'secondmind-labs', '...

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id  ... payload.pull_request.merged_by.site_admin
# 0   16781608999  ...                                       NaN
# 1   16781608961  ...                                       NaN
# 2   16781609009  ...                                       NaN
# 3   16781608975  ...                                       NaN
# 4   16781608976  ...                                       NaN
# 5   16781608965  ...                                       NaN
# 6   16781608969  ...                                       NaN
# 7   16781608967  ...                                       NaN
# 8   16781608991  ...                                       NaN
# 9   16781608912  ...                                       NaN
# 10  16781608926  ...                                       NaN
# 11  16781608899  ...                                       NaN
# 12  16781608947  ...                                       NaN
# 13  16781608922  ...                                       NaN
# 14  16781608934  ...                                       NaN
# 15  16781608935  ...                                       NaN
# 16  16781608884  ...                                       NaN
# 17  16781608885  ...                                       NaN
# 18  16781608908  ...                                       NaN
# 19  16781608902  ...                                       NaN
# 20  16781608910  ...                                       NaN
# 21  16781608873  ...                                       NaN
# 22  16781608863  ...                                       NaN
# 23  16781608875  ...                                       NaN
# 24  16781608852  ...                                       NaN
# 25  16781608842  ...                                       NaN
# 26  16781608864  ...                                       NaN
# 27  16781608833  ...                                       NaN
# 28  16781608871  ...                                     False
# 29  16781608837  ...                                       NaN
#
# [30 rows x 523 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'timestamp': 1631698420,
#  'iss_position': {'latitude': '-40.3667', 'longitude': '-19.0158'}}

# %%
from datetime import datetime
datetime.fromtimestamp(1631698420) #seconds that have elapsed since January 1st, 1970 00:00:00 UTC https://kb.narrative.io/what-is-unix-time
# Out:
# datetime.datetime(2021, 9, 15, 11, 33, 40)

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack Spain
coordinates = {"lat": 41.397730, "lon": 2.190290}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=41.39773&lon=2.19029'

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json?lat=41.39773&lon=2.19029")

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1631698305,
#   'latitude': 41.39773,
#   'longitude': 2.19029,
#   'passes': 5},
#  'response': [{'duration': 385, 'risetime': 1631728668},
#   {'duration': 645, 'risetime': 1631734305},
#   {'duration': 629, 'risetime': 1631740131},
#   {'duration': 576, 'risetime': 1631746019},
#   {'duration': 610, 'risetime': 1631751869}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1604442746)
# Out:
# datetime.datetime(2020, 11, 3, 23, 32, 26)

# %%
pd.to_datetime(1604442746, unit="s")
# Out:
# Timestamp('2020-11-03 22:32:26')

# %%
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1,'/content/drive/MyDrive/Credentials/')
from config import *

# %% [markdown]
# ### Weather API
#
# Create an account at RapidAPI and "subscribe" to the Weather API: https://rapidapi.com/weatherbit/api/

# %%
import requests

## https://rapidapi.com/community/api/open-weather-map/
url = "https://weatherbit-v1-mashape.p.rapidapi.com/current"

#My location coords: lat: 40.545111, lon: -4.204942
querystring = {"lon":"-4.204942","lat":"40.545111"}
querystring["units"] ="metric"
querystring["lang"] = "en"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-245a1b6a69ab> in <module>
#      10
#      11 headers = {
# ---> 12     'x-rapidapi-key': x_rapidapi_key,
#      13     'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
#      14     }
#
# NameError: name 'x_rapidapi_key' is not defined

# %%
results = response.json()
print(results)
type(results)
# Out:
# {'message': 'success', 'request': {'altitude': 100, 'datetime': 1631698305, 'latitude': 41.39773, 'longitude': 2.19029, 'passes': 5}, 'response': [{'duration': 385, 'risetime': 1631728668}, {'duration': 645, 'risetime': 1631734305}, {'duration': 629, 'risetime': 1631740131}, {'duration': 576, 'risetime': 1631746019}, {'duration': 610, 'risetime': 1631751869}]}
# dict

# %%
results.keys()
# Out:
# dict_keys(['message', 'request', 'response'])

# %%
results['data']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-e05258f859dc> in <module>
# ----> 1 results['data']
#
# KeyError: 'data'

# %% [markdown]
# Getting the forecast for the next 5 days at a 3h intervals

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
results = response.json()
print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-2fd22f51745b> in <module>
#       4
#       5 headers = {
# ----> 6     'x-rapidapi-key': x_rapidapi_key,
#       7     'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
#       8     }
#
# NameError: name 'x_rapidapi_key' is not defined

# %%
results['data']
# Out:
# [{'app_temp': 22.4,
#   'clouds': 69,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 69,
#   'datetime': '2021-06-15:09',
#   'dewpt': 7.9,
#   'dhi': 103.41,
#   'dni': 868.79,
#   'ghi': 717.09,
#   'ozone': 336,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.001953125,
#   'pres': 884.145,
#   'rh': 39,
#   'slp': 1018.79,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 564.782,
#   'temp': 23,
#   'timestamp_local': '2021-06-15T11:00:00',
#   'timestamp_utc': '2021-06-15T09:00:00',
#   'ts': 1623747600,
#   'uv': 2.81755,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'ENE',
#   'wind_cdir_full': 'east-northeast',
#   'wind_dir': 78,
#   'wind_gust_spd': 11.5571,
#   'wind_spd': 4.07371},
#  {'app_temp': 26.2,
#   'clouds': 38,
#   'clouds_hi': 2,
#   'clouds_low': 0,
#   'clouds_mid': 39,
#   'datetime': '2021-06-15:12',
#   'dewpt': 6,
#   'dhi': 117.62,
#   'dni': 937.94,
#   'ghi': 1002.88,
#   'ozone': 328,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 883.112,
#   'rh': 27,
#   'slp': 1016.89,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 974.853,
#   'temp': 26.8,
#   'timestamp_local': '2021-06-15T14:00:00',
#   'timestamp_utc': '2021-06-15T12:00:00',
#   'ts': 1623758400,
#   'uv': 7.58151,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02d'},
#   'wind_cdir': 'ESE',
#   'wind_cdir_full': 'east-southeast',
#   'wind_dir': 111,
#   'wind_gust_spd': 11.7118,
#   'wind_spd': 5.50618},
#  {'app_temp': 26.9,
#   'clouds': 76,
#   'clouds_hi': 43,
#   'clouds_low': 0,
#   'clouds_mid': 56,
#   'datetime': '2021-06-15:15',
#   'dewpt': 5.4,
#   'dhi': 107.98,
#   'dni': 892.15,
#   'ghi': 801.62,
#   'ozone': 323,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.048828125,
#   'pres': 881.339,
#   'rh': 24,
#   'slp': 1014.46,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 565.139,
#   'temp': 28.1,
#   'timestamp_local': '2021-06-15T17:00:00',
#   'timestamp_utc': '2021-06-15T15:00:00',
#   'ts': 1623769200,
#   'uv': 3.15302,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 164,
#   'wind_gust_spd': 12.2921,
#   'wind_spd': 4.28592},
#  {'app_temp': 25.8,
#   'clouds': 80,
#   'clouds_hi': 12,
#   'clouds_low': 0,
#   'clouds_mid': 78,
#   'datetime': '2021-06-15:18',
#   'dewpt': 6,
#   'dhi': 68.69,
#   'dni': 647.18,
#   'ghi': 262.69,
#   'ozone': 320.5,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.021484375,
#   'pres': 880.719,
#   'rh': 28,
#   'slp': 1013.91,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 170.431,
#   'temp': 26.4,
#   'timestamp_local': '2021-06-15T20:00:00',
#   'timestamp_utc': '2021-06-15T18:00:00',
#   'ts': 1623780000,
#   'uv': 0.813903,
#   'vis': 19.2,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'S',
#   'wind_cdir_full': 'south',
#   'wind_dir': 169,
#   'wind_gust_spd': 10.1157,
#   'wind_spd': 4.75035},
#  {'app_temp': 20.8,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 8,
#   'clouds_mid': 81,
#   'datetime': '2021-06-15:21',
#   'dewpt': 9.5,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 319,
#   'pod': 'n',
#   'pop': 10,
#   'precip': 0.095703125,
#   'pres': 881.045,
#   'rh': 48,
#   'slp': 1015.38,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 21.4,
#   'timestamp_local': '2021-06-15T23:00:00',
#   'timestamp_utc': '2021-06-15T21:00:00',
#   'ts': 1623790800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 48,
#   'wind_gust_spd': 7.37562,
#   'wind_spd': 2.08412},
#  {'app_temp': 18.1,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 4,
#   'clouds_mid': 70,
#   'datetime': '2021-06-16:00',
#   'dewpt': 11.9,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 324.75,
#   'pod': 'n',
#   'pop': 25,
#   'precip': 0.33984375,
#   'pres': 881.915,
#   'rh': 67,
#   'slp': 1017.05,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.4,
#   'timestamp_local': '2021-06-16T02:00:00',
#   'timestamp_utc': '2021-06-16T00:00:00',
#   'ts': 1623801600,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04n'},
#   'wind_cdir': 'E',
#   'wind_cdir_full': 'east',
#   'wind_dir': 90,
#   'wind_gust_spd': 9.4193,
#   'wind_spd': 1.0167},
#  {'app_temp': 17.4,
#   'clouds': 73,
#   'clouds_hi': 0,
#   'clouds_low': 24,
#   'clouds_mid': 63,
#   'datetime': '2021-06-16:03',
#   'dewpt': 11,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 323,
#   'pod': 'n',
#   'pop': 15,
#   'precip': 0.068359375,
#   'pres': 879.474,
#   'rh': 67,
#   'slp': 1014.45,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 17.4,
#   'timestamp_local': '2021-06-16T05:00:00',
#   'timestamp_utc': '2021-06-16T03:00:00',
#   'ts': 1623812400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02n'},
#   'wind_cdir': 'ENE',
#   'wind_cdir_full': 'east-northeast',
#   'wind_dir': 62,
#   'wind_gust_spd': 11.6762,
#   'wind_spd': 3.34812},
#  {'app_temp': 17,
#   'clouds': 62,
#   'clouds_hi': 0,
#   'clouds_low': 21,
#   'clouds_mid': 54,
#   'datetime': '2021-06-16:06',
#   'dewpt': 10.8,
#   'dhi': 55.42,
#   'dni': 536.17,
#   'ghi': 159.75,
#   'ozone': 321.25,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 879.611,
#   'rh': 69,
#   'slp': 1014.84,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 136.165,
#   'temp': 17,
#   'timestamp_local': '2021-06-16T08:00:00',
#   'timestamp_utc': '2021-06-16T06:00:00',
#   'ts': 1623823200,
#   'uv': 0.894861,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 48,
#   'wind_gust_spd': 11.2242,
#   'wind_spd': 2.06524},
#  {'app_temp': 19.3,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 30,
#   'clouds_mid': 51,
#   'datetime': '2021-06-16:09',
#   'dewpt': 11.3,
#   'dhi': 103.38,
#   'dni': 868.55,
#   'ghi': 716.68,
#   'ozone': 318.75,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 879.427,
#   'rh': 60,
#   'slp': 1014.29,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 179.17,
#   'temp': 19.7,
#   'timestamp_local': '2021-06-16T11:00:00',
#   'timestamp_utc': '2021-06-16T09:00:00',
#   'ts': 1623834000,
#   'uv': 1.67897,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'E',
#   'wind_cdir_full': 'east',
#   'wind_dir': 97,
#   'wind_gust_spd': 11.2175,
#   'wind_spd': 2.20589},
#  {'app_temp': 22.9,
#   'clouds': 56,
#   'clouds_hi': 8,
#   'clouds_low': 30,
#   'clouds_mid': 38,
#   'datetime': '2021-06-16:12',
#   'dewpt': 11.1,
#   'dhi': 117.6,
#   'dni': 937.81,
#   'ghi': 1002.87,
#   'ozone': 320.5,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.146484375,
#   'pres': 878.984,
#   'rh': 48,
#   'slp': 1013.18,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 898.122,
#   'temp': 23.2,
#   'timestamp_local': '2021-06-16T14:00:00',
#   'timestamp_utc': '2021-06-16T12:00:00',
#   'ts': 1623844800,
#   'uv': 6.33404,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 160,
#   'wind_gust_spd': 13.1602,
#   'wind_spd': 4.33191},
#  {'app_temp': 23.8,
#   'clouds': 82,
#   'clouds_hi': 8,
#   'clouds_low': 64,
#   'clouds_mid': 63,
#   'datetime': '2021-06-16:15',
#   'dewpt': 8.7,
#   'dhi': 108,
#   'dni': 892.19,
#   'ghi': 802.25,
#   'ozone': 328.25,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.01171875,
#   'pres': 876.801,
#   'rh': 38,
#   'slp': 1010.28,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 495.815,
#   'temp': 24.3,
#   'timestamp_local': '2021-06-16T17:00:00',
#   'timestamp_utc': '2021-06-16T15:00:00',
#   'ts': 1623855600,
#   'uv': 2.88811,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 194,
#   'wind_gust_spd': 13.1986,
#   'wind_spd': 6.2823},
#  {'app_temp': 22.4,
#   'clouds': 82,
#   'clouds_hi': 19,
#   'clouds_low': 56,
#   'clouds_mid': 69,
#   'datetime': '2021-06-16:18',
#   'dewpt': 9.1,
#   'dhi': 68.79,
#   'dni': 647.94,
#   'ghi': 263.66,
#   'ozone': 326.75,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.06640625,
#   'pres': 876.411,
#   'rh': 42,
#   'slp': 1010.01,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 162.95,
#   'temp': 22.9,
#   'timestamp_local': '2021-06-16T20:00:00',
#   'timestamp_utc': '2021-06-16T18:00:00',
#   'ts': 1623866400,
#   'uv': 0.793887,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SW',
#   'wind_cdir_full': 'southwest',
#   'wind_dir': 220,
#   'wind_gust_spd': 11.1933,
#   'wind_spd': 3.96155},
#  {'app_temp': 18.1,
#   'clouds': 94,
#   'clouds_hi': 62,
#   'clouds_low': 56,
#   'clouds_mid': 84,
#   'datetime': '2021-06-16:21',
#   'dewpt': 10.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 327.25,
#   'pod': 'n',
#   'pop': 15,
#   'precip': 0.193359375,
#   'pres': 878.112,
#   'rh': 59,
#   'slp': 1012.83,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.6,
#   'timestamp_local': '2021-06-16T23:00:00',
#   'timestamp_utc': '2021-06-16T21:00:00',
#   'ts': 1623877200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04n'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 126,
#   'wind_gust_spd': 7.01437,
#   'wind_spd': 1.32861},
#  {'app_temp': 15.8,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2021-06-17:00',
#   'dewpt': 10.5,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 327.25,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 877.269,
#   'rh': 72,
#   'slp': 1012.48,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 15.8,
#   'timestamp_local': '2021-06-17T02:00:00',
#   'timestamp_utc': '2021-06-17T00:00:00',
#   'ts': 1623888000,
#   'uv': 0,
#   'vis': 10.008,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 327,
#   'wind_gust_spd': 6.08424,
#   'wind_spd': 1.71289},
#  {'app_temp': 14.8,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 27,
#   'clouds_mid': 2,
#   'datetime': '2021-06-17:03',
#   'dewpt': 10.6,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 330.75,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 876.7,
#   'rh': 78,
#   'slp': 1011.99,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 14.8,
#   'timestamp_local': '2021-06-17T05:00:00',
#   'timestamp_utc': '2021-06-17T03:00:00',
#   'ts': 1623898800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 2,
#   'wind_gust_spd': 5.55667,
#   'wind_spd': 1.72096},
#  {'app_temp': 15.5,
#   'clouds': 88,
#   'clouds_hi': 67,
#   'clouds_low': 37,
#   'clouds_mid': 45,
#   'datetime': '2021-06-17:06',
#   'dewpt': 11.7,
#   'dhi': 55.36,
#   'dni': 535.63,
#   'ghi': 159.4,
#   'ozone': 336,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 876.228,
#   'rh': 80,
#   'slp': 1011.42,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 81.9911,
#   'temp': 15.5,
#   'timestamp_local': '2021-06-17T08:00:00',
#   'timestamp_utc': '2021-06-17T06:00:00',
#   'ts': 1623909600,
#   'uv': 0.608304,
#   'vis': 10.728,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 5,
#   'wind_gust_spd': 4.37833,
#   'wind_spd': 1.08316},
#  {'app_temp': 17.2,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 72,
#   'clouds_mid': 30,
#   'datetime': '2021-06-17:09',
#   'dewpt': 13.5,
#   'dhi': 103.34,
#   'dni': 868.31,
#   'ghi': 716.21,
#   'ozone': 339.25,
#   'pod': 'd',
#   'pop': 45,
#   'precip': 0.75,
#   'pres': 876.576,
#   'rh': 80,
#   'slp': 1011.65,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 136.08,
#   'temp': 17.2,
#   'timestamp_local': '2021-06-17T11:00:00',
#   'timestamp_utc': '2021-06-17T09:00:00',
#   'ts': 1623920400,
#   'uv': 1.66392,
#   'vis': 24.128,
#   'weather': {'code': 201,
#    'description': 'Thunderstorm with rain',
#    'icon': 't02d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 137,
#   'wind_gust_spd': 6.34957,
#   'wind_spd': 1.5818},
#  {'app_temp': 17.1,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 71,
#   'clouds_mid': 33,
#   'datetime': '2021-06-17:12',
#   'dewpt': 14.6,
#   'dhi': 117.59,
#   'dni': 937.68,
#   'ghi': 1002.82,
#   'ozone': 334.75,
#   'pod': 'd',
#   'pop': 45,
#   'precip': 0.89453125,
#   'pres': 876.039,
#   'rh': 87,
#   'slp': 1011.09,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 190.536,
#   'temp': 17.1,
#   'timestamp_local': '2021-06-17T14:00:00',
#   'timestamp_utc': '2021-06-17T12:00:00',
#   'ts': 1623931200,
#   'uv': 3.18526,
#   'vis': 24.128,
#   'weather': {'code': 201,
#    'description': 'Thunderstorm with rain',
#    'icon': 't02d'},
#   'wind_cdir': 'ESE',
#   'wind_cdir_full': 'east-southeast',
#   'wind_dir': 116,
#   'wind_gust_spd': 5.97595,
#   'wind_spd': 1.59535},
#  {'app_temp': 17.2,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 73,
#   'clouds_mid': 18,
#   'datetime': '2021-06-17:15',
#   'dewpt': 14.8,
#   'dhi': 108.02,
#   'dni': 892.23,
#   'ghi': 802.82,
#   'ozone': 333,
#   'pod': 'd',
#   'pop': 30,
#   'precip': 0.4140625,
#   'pres': 874.932,
#   'rh': 87,
#   'slp': 1009.84,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 152.536,
#   'temp': 17.2,
#   'timestamp_local': '2021-06-17T17:00:00',
#   'timestamp_utc': '2021-06-17T15:00:00',
#   'ts': 1623942000,
#   'uv': 2.05182,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 144,
#   'wind_gust_spd': 9.99384,
#   'wind_spd': 1.89453},
#  {'app_temp': 16,
#   'clouds': 79,
#   'clouds_hi': 14,
#   'clouds_low': 73,
#   'clouds_mid': 16,
#   'datetime': '2021-06-17:18',
#   'dewpt': 13.9,
#   'dhi': 68.88,
#   'dni': 648.64,
#   'ghi': 264.57,
#   'ozone': 338.75,
#   'pod': 'd',
#   'pop': 65,
#   'precip': 1.90234375,
#   'pres': 875.149,
#   'rh': 89,
#   'slp': 1010.34,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 168.418,
#   'temp': 16,
#   'timestamp_local': '2021-06-17T20:00:00',
#   'timestamp_utc': '2021-06-17T18:00:00',
#   'ts': 1623952800,
#   'uv': 0.821966,
#   'vis': 24.128,
#   'weather': {'code': 201,
#    'description': 'Thunderstorm with rain',
#    'icon': 't02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 55,
#   'wind_gust_spd': 11.0891,
#   'wind_spd': 0.200486},
#  {'app_temp': 14.9,
#   'clouds': 73,
#   'clouds_hi': 0,
#   'clouds_low': 49,
#   'clouds_mid': 55,
#   'datetime': '2021-06-17:21',
#   'dewpt': 13.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 344.5,
#   'pod': 'n',
#   'pop': 55,
#   'precip': 1.25390625,
#   'pres': 876.497,
#   'rh': 91,
#   'slp': 1012.01,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 14.9,
#   'timestamp_local': '2021-06-17T23:00:00',
#   'timestamp_utc': '2021-06-17T21:00:00',
#   'ts': 1623963600,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04n'},
#   'wind_cdir': 'NNE',
#   'wind_cdir_full': 'north-northeast',
#   'wind_dir': 33,
#   'wind_gust_spd': 6.10028,
#   'wind_spd': 0.601711},
#  {'app_temp': 13.1,
#   'clouds': 12,
#   'clouds_hi': 2,
#   'clouds_low': 4,
#   'clouds_mid': 5,
#   'datetime': '2021-06-18:00',
#   'dewpt': 11.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 343.25,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 876.513,
#   'rh': 89,
#   'slp': 1012.39,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 13.1,
#   'timestamp_local': '2021-06-18T02:00:00',
#   'timestamp_utc': '2021-06-18T00:00:00',
#   'ts': 1623974400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 352,
#   'wind_gust_spd': 4.04717,
#   'wind_spd': 0.758533},
#  {'app_temp': 12,
#   'clouds': 50,
#   'clouds_hi': 1,
#   'clouds_low': 50,
#   'clouds_mid': 2,
#   'datetime': '2021-06-18:03',
#   'dewpt': 10.7,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 343.25,
#   'pod': 'n',
#   'pop': 15,
#   'precip': 0.03125,
#   'pres': 876.44,
#   'rh': 92,
#   'slp': 1012.57,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 12,
#   'timestamp_local': '2021-06-18T05:00:00',
#   'timestamp_utc': '2021-06-18T03:00:00',
#   'ts': 1623985200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 345,
#   'wind_gust_spd': 6.70735,
#   'wind_spd': 0.87161},
#  {'app_temp': 12,
#   'clouds': 88,
#   'clouds_hi': 0,
#   'clouds_low': 78,
#   'clouds_mid': 30,
#   'datetime': '2021-06-18:06',
#   'dewpt': 10.7,
#   'dhi': 55.29,
#   'dni': 535,
#   'ghi': 158.97,
#   'ozone': 343.75,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 877.36,
#   'rh': 93,
#   'slp': 1013.68,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 66.33,
#   'temp': 12,
#   'timestamp_local': '2021-06-18T08:00:00',
#   'timestamp_utc': '2021-06-18T06:00:00',
#   'ts': 1623996000,
#   'uv': 0.593585,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'S',
#   'wind_cdir_full': 'south',
#   'wind_dir': 177,
#   'wind_gust_spd': 7.49278,
#   'wind_spd': 0.468219},
#  {'app_temp': 19.7,
#   'clouds': 90,
#   'clouds_hi': 90,
#   'clouds_low': 46,
#   'clouds_mid': 0,
#   'datetime': '2021-06-18:09',
#   'dewpt': 8.1,
#   'dhi': 103.3,
#   'dni': 868.06,
#   'ghi': 715.69,
#   'ozone': 345,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 45,
#   'slp': 1012.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 344.066,
#   'temp': 20.5,
#   'timestamp_local': '2021-06-18T11:00:00',
#   'timestamp_utc': '2021-06-18T09:00:00',
#   'ts': 1624006800,
#   'uv': 2.0374,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 138,
#   'wind_gust_spd': 5.41016,
#   'wind_spd': 3.7763},
#  {'app_temp': 22.4,
#   'clouds': 24,
#   'clouds_hi': 2,
#   'clouds_low': 24,
#   'clouds_mid': 0,
#   'datetime': '2021-06-18:12',
#   'dewpt': 8.8,
#   'dhi': 117.58,
#   'dni': 937.55,
#   'ghi': 1002.73,
#   'ozone': 344.25,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 40,
#   'slp': 1012,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 997.187,
#   'temp': 23,
#   'timestamp_local': '2021-06-18T14:00:00',
#   'timestamp_utc': '2021-06-18T12:00:00',
#   'ts': 1624017600,
#   'uv': 8.58676,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 147,
#   'wind_gust_spd': 6.69922,
#   'wind_spd': 4.54761},
#  {'app_temp': 23.5,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 63,
#   'clouds_mid': 32,
#   'datetime': '2021-06-18:15',
#   'dewpt': 7.5,
#   'dhi': 108.04,
#   'dni': 892.26,
#   'ghi': 803.36,
#   'ozone': 343.5,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 905,
#   'rh': 34,
#   'slp': 1009.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 200.84,
#   'temp': 24.2,
#   'timestamp_local': '2021-06-18T17:00:00',
#   'timestamp_utc': '2021-06-18T15:00:00',
#   'ts': 1624028400,
#   'uv': 2.04829,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 208,
#   'wind_gust_spd': 5.91797,
#   'wind_spd': 2.26834},
#  {'app_temp': 22.7,
#   'clouds': 64,
#   'clouds_hi': 57,
#   'clouds_low': 18,
#   'clouds_mid': 19,
#   'datetime': '2021-06-18:18',
#   'dewpt': 8.5,
#   'dhi': 68.97,
#   'dni': 649.29,
#   'ghi': 265.41,
#   'ozone': 343.5,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 904.5,
#   'rh': 38,
#   'slp': 1008.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 220.884,
#   'temp': 23.3,
#   'timestamp_local': '2021-06-18T20:00:00',
#   'timestamp_utc': '2021-06-18T18:00:00',
#   'ts': 1624039200,
#   'uv': 0.994731,
#   'vis': 24.128,
#   'weather': {'code': 803, 'description': 'Broken clouds', 'icon': 'c03d'},
#   'wind_cdir': 'WSW',
#   'wind_cdir_full': 'west-southwest',
#   'wind_dir': 239,
#   'wind_gust_spd': 4.63281,
#   'wind_spd': 2.69643},
#  {'app_temp': 18.3,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 6,
#   'clouds_mid': 79,
#   'datetime': '2021-06-18:21',
#   'dewpt': 7.7,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 340.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 905.5,
#   'rh': 50,
#   'slp': 1010.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.3,
#   'timestamp_local': '2021-06-18T23:00:00',
#   'timestamp_utc': '2021-06-18T21:00:00',
#   'ts': 1624050000,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 351,
#   'wind_gust_spd': 2.12695,
#   'wind_spd': 2.41283},
#  {'app_temp': 16.1,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 99,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:00',
#   'dewpt': 10.2,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 337.75,
#   'pod': 'n',
#   'pop': 10,
#   'precip': 0.125,
#   'pres': 905.5,
#   'rh': 68,
#   'slp': 1011.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 16.1,
#   'timestamp_local': '2021-06-19T02:00:00',
#   'timestamp_utc': '2021-06-19T00:00:00',
#   'ts': 1624060800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 338,
#   'wind_gust_spd': 0.812988,
#   'wind_spd': 0.61213},
#  {'app_temp': 13.4,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 100,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:03',
#   'dewpt': 12.9,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 333.25,
#   'pod': 'n',
#   'pop': 90,
#   'precip': 7.4375,
#   'pres': 905,
#   'rh': 97,
#   'slp': 1011.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 13.4,
#   'timestamp_local': '2021-06-19T05:00:00',
#   'timestamp_utc': '2021-06-19T03:00:00',
#   'ts': 1624071600,
#   'uv': 0,
#   'vis': 1.0125,
#   'weather': {'code': 502, 'description': 'Heavy rain', 'icon': 'r03n'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 208,
#   'wind_gust_spd': 7.69922,
#   'wind_spd': 4.79758},
#  {'app_temp': 11.7,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 100,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:06',
#   'dewpt': 9.4,
#   'dhi': 55.21,
#   'dni': 534.26,
#   'ghi': 158.47,
#   'ozone': 342.75,
#   'pod': 'd',
#   'pop': 40,
#   'precip': 0.6875,
#   'pres': 908,
#   'rh': 86,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 30.1093,
#   'temp': 11.7,
#   'timestamp_local': '2021-06-19T08:00:00',
#   'timestamp_utc': '2021-06-19T06:00:00',
#   'ts': 1624082400,
#   'uv': 0.472565,
#   'vis': 5.4,
#   'weather': {'code': 301, 'description': 'Drizzle', 'icon': 'd02d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 199,
#   'wind_gust_spd': 5.59766,
#   'wind_spd': 2.69708},
#  {'app_temp': 11.4,
#   'clouds': 100,
#   'clouds_hi': 14,
#   'clouds_low': 100,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:09',
#   'dewpt': 10.3,
#   'dhi': 103.26,
#   'dni': 867.79,
#   'ghi': 715.12,
#   'ozone': 350.75,
#   'pod': 'd',
#   'pop': 10,
#   'precip': 0.125,
#   'pres': 907.5,
#   'rh': 93,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 71.512,
#   'temp': 11.4,
#   'timestamp_local': '2021-06-19T11:00:00',
#   'timestamp_utc': '2021-06-19T09:00:00',
#   'ts': 1624093200,
#   'uv': 1.65327,
#   'vis': 0.869,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 139,
#   'wind_gust_spd': 4.59766,
#   'wind_spd': 2.73987},
#  {'app_temp': 15.1,
#   'clouds': 92,
#   'clouds_hi': 8,
#   'clouds_low': 92,
#   'clouds_mid': 32,
#   'datetime': '2021-06-19:12',
#   'dewpt': 10,
#   'dhi': 117.56,
#   'dni': 937.42,
#   'ghi': 1002.62,
#   'ozone': 351,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.0625,
#   'pres': 907.5,
#   'rh': 72,
#   'slp': 1014,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 434.972,
#   'temp': 15.1,
#   'timestamp_local': '2021-06-19T14:00:00',
#   'timestamp_utc': '2021-06-19T12:00:00',
#   'ts': 1624104000,
#   'uv': 3.7363,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 162,
#   'wind_gust_spd': 3.10547,
#   'wind_spd': 2.37379},
#  {'app_temp': 18,
#   'clouds': 69,
#   'clouds_hi': 55,
#   'clouds_low': 40,
#   'clouds_mid': 56,
#   'datetime': '2021-06-19:15',
#   'dewpt': 9.3,
#   'dhi': 108.05,
#   'dni': 892.29,
#   'ghi': 803.85,
#   'ozone': 352.75,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 56,
#   'slp': 1013,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 633.115,
#   'temp': 18,
#   'timestamp_local': '2021-06-19T17:00:00',
#   'timestamp_utc': '2021-06-19T15:00:00',
#   'ts': 1624114800,
#   'uv': 3.45731,
#   'vis': 24.128,
#   'weather': {'code': 803, 'description': 'Broken clouds', 'icon': 'c03d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 160,
#   'wind_gust_spd': 3.32227,
#   'wind_spd': 2.62303},
#  {'app_temp': 18.1,
#   'clouds': 10,
#   'clouds_hi': 10,
#   'clouds_low': 1,
#   'clouds_mid': 6,
#   'datetime': '2021-06-19:18',
#   'dewpt': 8.7,
#   'dhi': 69.05,
#   'dni': 649.88,
#   'ghi': 266.18,
#   'ozone': 351,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 54,
#   'slp': 1013,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 266.103,
#   'temp': 18.1,
#   'timestamp_local': '2021-06-19T20:00:00',
#   'timestamp_utc': '2021-06-19T18:00:00',
#   'ts': 1624125600,
#   'uv': 1.657,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02d'},
#   'wind_cdir': 'S',
#   'wind_cdir_full': 'south',
#   'wind_dir': 177,
#   'wind_gust_spd': 3.30078,
#   'wind_spd': 2.27588},
#  {'app_temp': 14,
#   'clouds': 100,
#   'clouds_hi': 21,
#   'clouds_low': 3,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:21',
#   'dewpt': 9,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 347.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 908.5,
#   'rh': 72,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 14,
#   'timestamp_local': '2021-06-19T23:00:00',
#   'timestamp_utc': '2021-06-19T21:00:00',
#   'ts': 1624136400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 144,
#   'wind_gust_spd': 1.125,
#   'wind_spd': 0.953986},
#  {'app_temp': 12.7,
#   'clouds': 64,
#   'clouds_hi': 64,
#   'clouds_low': 2,
#   'clouds_mid': 5,
#   'datetime': '2021-06-20:00',
#   'dewpt': 9.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 348.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 908.5,
#   'rh': 79,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 12.7,
#   'timestamp_local': '2021-06-20T02:00:00',
#   'timestamp_utc': '2021-06-20T00:00:00',
#   'ts': 1624147200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 803, 'description': 'Broken clouds', 'icon': 'c03n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 343,
#   'wind_gust_spd': 0.899902,
#   'wind_spd': 0.956497},
#  {'app_temp': 11.6,
#   'clouds': 72,
#   'clouds_hi': 0,
#   'clouds_low': 2,
#   'clouds_mid': 72,
#   'datetime': '2021-06-20:03',
#   'dewpt': 9.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 350.75,
#   'pod': 'n',
#   'pop': 25,
#   'precip': 0.3125,
#   'pres': 908.5,
#   'rh': 85,
#   'slp': 1015.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 11.6,
#   'timestamp_local': '2021-06-20T05:00:00',
#   'timestamp_utc': '2021-06-20T03:00:00',
#   'ts': 1624158000,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 6,
#   'wind_gust_spd': 1.10254,
#   'wind_spd': 1.19666},
#  {'app_temp': 13,
#   'clouds': 88,
#   'clouds_hi': 0,
#   'clouds_low': 22,
#   'clouds_mid': 88,
#   'datetime': '2021-06-20:06',
#   'dewpt': 10.2,
#   'dhi': 55.12,
#   'dni': 533.43,
#   'ghi': 157.9,
#   'ozone': 352,
#   'pod': 'd',
#   'pop': 50,
#   'precip': 1.0625,
#   'pres': 908,
#   'rh': 83,
#   'slp': 1014.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 73.4744,
#   'temp': 13,
#   'timestamp_local': '2021-06-20T08:00:00',
#   'timestamp_utc': '2021-06-20T06:00:00',
#   'ts': 1624168800,
#   'uv': 0.586461,
#   'vis': 12.568,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04d'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 348,
#   'wind_gust_spd': 0.911621,
#   'wind_spd': 0.800612}]

# %%
len(results['data'])
# Out:
# 40
